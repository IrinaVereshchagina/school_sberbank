# %% [markdown]
# # Практика

# %% [markdown]
# ## Определение вероятности. События

# %% [markdown]
# ### Задача 1
# Брошено две монеты. Найти вероятность того, что монеты выпали разными сторонами.
#
# A = \{монеты выпали разными сторонами\}
#
# $P(A) = \frac{|\{монеты\ выпали\ разными\ сторонами\}|}{|\Omega|} $
#
# $\Omega = (РР), (ОО), (РО), (ОР)$
#
# $P(A) = \frac{2}{4} = \frac{1}{2}$

# %% [markdown]
# ### Задача 2
# Брошено три монеты. Описать множество всех элементарных событий. Найти вероятности следующих событий:
#
#
# 1.   A = {не выпало ни одного герба}
# 2.   B = {выпало четное число гербов}
# 3.   C = {на третьей монете выпал герб}
#
# $\Omega = РРР, РРГ, РГГ, ГГГ, РГР, ГРГ, ГРР, ГГР$
#
# $P(A) = \frac{1}{8}$
#
# $P(B) = \frac{4}{8} = \frac{1}{2}$
#
# $P(C) = \frac{4}{8} = \frac{1}{2}$

# %% [markdown]
# Предлагается также решить задачи:
#
# ### Задача 3
# Из двух претендентов E и L на ответственную должность три члена комиссии должны отобрать одного. Каждый член комиссии должен указать либо одного достойного, либо забраковать обоих. Претендент считается выбранным, если он был признана достойным хотя бы двумя членами комиссии.
# Найти вероятность событий:
#
# A = {реокмендован L}, B = {рекомендован E}
# Чтобы наступило событие А хотя бы 2 человка должны отобрать кандидата Е
# Чтобы наступило событие В хотя бы 2 человека должны отобрать кандидата L
#
# Кроме того, члены комиссии могут не выбрать никого.
#
# Записываем варианты исходов: 3Х3Х3= 27 вариантов
# Найдем варианты выбора которые приведут к событию А, то есть если кандидата Lне рекомендует только 1 член комиссии, либо его рекомендует 2 или даже все 3
# запишу эти варианты ={LLO, LLE, LOL, LEL, LLL, OLL, ELL} их семь значит вероятность 7 из 27 А=7/27
#
# Аналогично находим варианты выбора, которые приведут к событию В, то есть если кандидата E не рекомендует 1 член комисии и 2 оставшихся будут за него.
# В={ЕЕО, EEL, EOE, ELE, EEE, OEE, LEE} их тоже получилось 7
# тогда B= 7/27
#
#
#
# -----------------------------
#
# ### Задача 4
# Брошено две игральных кости. Описать множество элементарных событий. Найти вероятности событий:
#
# A = {вышло две "шестерки"}
#
# Вероятность что выпала шестерка 1/6 на одной кости, соответстветственно для наступления события А у нас вероятность А=1/6 умножим 1/6 А=1/36
#
# B = {сумма выпавших очков не меньше 11}
# исходы для наступления события В это значение на костях: 5 и 6, 6 и 5, 6 и 6.
# То есть 3 исхода из 36 возможных В=3/36 или 1/12
#
#
# C = {не выпала ни одна "шестерка"}
# у нас вероятность что на одной кости выпадет 6 равно 1/6, значит вероятность что на одной кости не выпадет 6 равно 5/6 , следовательно для нахождения вероятности невыпадения 6 на двух костях мы 5/6 умножим 5/6 итого 25/36

# %% [markdown]
# ## Вероятность суммы событий

# %% [markdown]
# ### Задача 5
# Брошены две игральные кости. Найти вероятность события D = {выпала хотя бы одна шестёрка}
#
# $E_1 = \{на\ первой\ кости\ выпала\ 6ка\}$
#
# $E_2 = \{на\ второй\ кости\ выпала\ 6ка\}$
#
# $D = \{выпала\ хотя\ бы\ одна\ шестёрка\}$
#
# $D = \{E_1 + E_2\} = \{на\ первой\ кости\ выпала\ 6ка\} \cup \{на\ второй\ кости\ выпала\ 6ка\} = \{только\ на\ первой\ кости\ выпала\ 6ка\} \cup \{только\ на\ второй\ кости\ выпала\ 6ка\} \cup \{на\ обеих\ 6\}$
#
# По формуле суммы вероятностей:
#
# $P(E_1+E_2) = P(E_1) + P(E_2) - P(E_1 E_2) = \frac{1}{6} + \frac{1}{6} - \frac{1}{36} = \frac{11}{36}$

# %% [markdown]
# Предлагается также решить задачи:
#
# ### Задача 6
# В телефонном номере три последние цифры стерлись. Считая, что все возможные значения стершихся цифр равновероятны, найти вероятность событий:
#
# A = {Стерлись различные цифры},
#
# B = {Стерлись одинаковые цифры},
#
# C = {Среди стершихся цифр хотя бы две совпадают},
#
# D = {Среди стершихся цифр хотя бы две различны}
#
# определим колличество исходов то есть всего у нас 10 цифр и 3 из них стерты, соответственно число вариантов это 10х10х10 или 10 в кубе
#
# у нас три цифры не известны, значит первая цифра имеет 10 вариантов, вторая соответственно 9 и третья восемь,
# таким образом вероятность события А=10Х9Х8/1000 итого 720/1000= 0,72
#
# стерлись одинаковые цифры то есть один вариант из 10 цифр, В=10/1000=0,01
#
# хотя бы две совпадают это событие противоположное событию А, значит можно вычислить вероятность события С так 1 - 0,72 = 0,28
#
# хотя бы две различны это событие противоположное событию В значит опять таки можно посчитать 1-0,01=0,99

# %% [markdown]
# ## Случайные величины

# %% [markdown]
# ### Задача 7
# В лотерее имеется 10 билетов, из которых один выигрышный. Размер выигрыша 10 ден. ед.; стоимость билета 1 ден ед. Найти закон распределения случайной величины X, равной чистому выигрышу участника лотереи, который вытаскивает билет первым.
#
# 1. -1 + 10 = 9
# 2. -1 + 0 = -1
#
# $P(X=9) = ? = \frac{1}{10}$
#
# $P(X=-1) = ? = \frac{9}{10}$

# %% [markdown]
# Предлагается также решить задачи:
#
# ### Задача 8
# Брошены две игральные кости. Найти закон распределения случайной величины $X$, равной сумме выпавших очков. Найти вероятности событий ${X <= 4}$, ${X > 4}$
#
#
# Найдем вероятности событий ${X<=4}$
# для выпадения 2х очков существует всего одна комбинация $1+1$ тогда вероятность такого исхода 1 из 36 или 1/36
# для выпадения 3х очков существует уже 2 комбинации $1+2$ и $2+1$ тогда вероятность такого исхода 2/36
# для выпадения 4х очков существует уже 3 комбинации $1+3$, $2+2$ , $2+1$ вероятность такого исхода 3/36
# Соответствественно общая вероятность будет $1/36+2/36+3/36=6/36 или 1/6$
#
# Теперь рассмотим вероятность события $X>4$ теоретически можно продолжить счет и дойдя до 12 высчитывать количество исходов, но можно и понять что если не меньше либо равно 4, значит больше. То есть вероятность данного событмия является противоположной событию с вероятностью $1/6$  а именно $6/6-1/6=5/6$

# %% [markdown]
# Таблица
# Сумма выпавших  очков       Вероятность X<=4
#
# 1.   1+1                             1/36
# 2.   1+2 и 2+1	                      2/36
# 3.    1+3 и 2+2 и 3+1	                3/36

# %% [markdown]
# ## Условные вероятности

# %% [markdown]
# ### Задача 9
# Из колоды (36 карт) вынимают последовательно без возвращения две карты. Найти вероятность того, что первой картой была шестерка, а второй — семерка. Найти условную вероятность того же события при условии, что обе карты бубновой масти.
#
# $A = \{Первой\ картой\ была\ 6,\ а\ второй\ 7\}$
#
# $P(A) = \frac{4 \cdot 4}{36 \cdot 36} = \frac{4}{315}$
#
# $B = \{обе\ карты\ бубновой\ масти\}$
#
# $P(AB) \neq P(A|B)$
#
# $P(AB) = \frac{1}{36*35}$
#
# $P(A|B) = \frac{P(AB)}{P(B)} = \frac{\frac{1}{36*35}}{\frac{8*9}{36*35}} = \frac{1}{72}$

# %% [markdown]
# Предлагается также решить задачи:
#
# ### Задача 10
# Из урны, содержащей два белых и три черных шара, последовательно извлекают два шара; вынутые шары не возвращаются. Если первый шар оказался черным, то перед вторым извлечением в урну добавляют белый шар. В противном случае состав оставшихся шаров не меняют. Найти вероятности событий:
#
# $A$ = {извлечены два белых шара},
#
# $B$ = {извлечены два черных шара}
#
# Указание. Пусть событие $C_1$ = {первый шар белый}, событие $C_2$ = {второй шар белый}. Тогда $A = C_1C_2$, $B = \overline C_1 \overline C_2$
#
# начинаем решение с определения всего у нас 5 шаров, то есть 5 исходов, из них два белых и три черных, теперь переходим к рассмотрению вероятностей:
# 1. извлечны два белых шара, итак если мы достаем первый шар, какая вероятность что он белый? 2 из 5 или 2/5, теперь мы вынули белый шар, всего осталось шаров 4 и по условию если вынут белый, мы шаров не добавляем, значит всего осталось шаров 4 и только один из них белый, то есть вероятность второго белого шара 1/4 теперь находим общую вероятность для двух белых шаров $2/5*1/4= 2/20=1/10$
#
# 2. извлечены 2 черных шара, рассуждаем аналогично при первом доставании шаров у нас вероятность достать черный равна 3/5, соответственно если мы вынули черный шар, то долдны доложить белый, тогда у нас станет снова 5 шаров и из них будет 2 черных и 3 белых, соответственно вероятность достать второй черный шар составит 2/5, найдем общую вероятность вытянуть два черных шара составит $3/5*2/5=6/25$

# %% [markdown]
# {A=C1C2 то есть событие A это произведение событий C1 и C2
# по теореме умножения вероятностей
#   P(A)=P(C1)P(C2|C1)}
#
# B событие противоположное событию и не забываем про добавление шаров

# %% [markdown]
# ## Независимость событий
# ### Задача 11
# Куплены два изделия, изготовленные на разных заводах. На первом заводе брак среди поступивших в продажу изделий составляет 2%, а на втором -- 5%. Найти вероятность событий:
#
# $A_0 = \{оба\ изделия\ бракованные\}$
#
# $A = \{хотя\ бы\ одно\ изделие\ стандартное\}$
#
# $A_1 = \{ровно\ одно\ изделие\ бракованное\}$
#
# Определим
#
# $C = \{купленное\ изделие\ первого\ завода\ бракованное\}$
#
# $D = \{купленное\ изделие\ второго\ завода\ бракованное\}$
#
# $A_0 = CD$
#
# $A = \overline{A_0}$
#
# $A_1 = \overline{C}D + \overline{D}C$
#
# $P(A_0) = 0.02 \cdot 0.05 = 0.001$
#
# $P(A) = 1 - 0.02 \cdot 0.05 = 0.999
#
# $P(A_1) = P(\overline{C}D + \overline{D}C) = P(\overline{C}D) + P(\overline{D}C) - P(\overline{C}D\overline{D}C) = (1-0.02)\cdot 0.05 + (1-0.05)\cdot 0.02 - 0$
