# %% [markdown]
# # Практика

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Выполните клетку ниже

# %%
# !wget https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv .
# Out:
# --2020-11-14 13:51:37--  https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv
# Resolving web.stanford.edu (web.stanford.edu)... 171.67.215.200
# Connecting to web.stanford.edu (web.stanford.edu)|171.67.215.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 44225 (43K) [text/csv]
# Saving to: ‘titanic.csv’
#
# titanic.csv         100%[===================>]  43.19K   160KB/s    in 0.3s
#
# 2020-11-14 13:51:37 (160 KB/s) - ‘titanic.csv’ saved [44225/44225]
#
# --2020-11-14 13:51:37--  http://./
# Resolving . (.)... failed: No address associated with hostname.
# wget: unable to resolve host address ‘.’
# FINISHED --2020-11-14 13:51:37--
# Total wall clock time: 0.9s
# Downloaded: 1 files, 43K in 0.3s (160 KB/s)

# %% [markdown]
# ## Задание 1
# Прочитайте файл в датафрейм, так, чтобы появились корректные колонки без каких-либо дополнительных действий, и отобразите первые 5 строчек

# %%
# ваш код тут
titanic = pd.read_csv('titanic.csv', header='infer', sep=',',)
titanic.head(5)
# Out:
#    Survived  Pclass  ... Parents/Children Aboard     Fare
# 0         0       3  ...                       0   7.2500
# 1         1       1  ...                       0  71.2833
# 2         1       3  ...                       0   7.9250
# 3         1       1  ...                       0  53.1000
# 4         0       3  ...                       0   8.0500
#
# [5 rows x 8 columns]

# %% [markdown]
# ## Задание 2
# Вывести имена всех выживших детей и их количество (у детей возраст < 18)

# %%
# вывожу основные данные по табоице
titanic.describe()
# Out:
#          Survived      Pclass  ...  Parents/Children Aboard       Fare
# count  887.000000  887.000000  ...               887.000000  887.00000
# mean     0.385569    2.305524  ...                 0.383315   32.30542
# std      0.487004    0.836662  ...                 0.807466   49.78204
# min      0.000000    1.000000  ...                 0.000000    0.00000
# 25%      0.000000    2.000000  ...                 0.000000    7.92500
# 50%      0.000000    3.000000  ...                 0.000000   14.45420
# 75%      1.000000    3.000000  ...                 0.000000   31.13750
# max      1.000000    3.000000  ...                 6.000000  512.32920
#
# [8 rows x 6 columns]

# %%
# ваш код тут
det = titanic[(titanic['Age'] < 18) & 
          (titanic['Survived'] == 1)] ['Name']
det
# Out:
# 9           Mrs. Nicholas (Adele Achem) Nasser
# 10              Miss. Marguerite Rut Sandstrom
# 22                          Miss. Anna McGowan
# 39                  Miss. Jamila Nicola-Yarred
# 42     Miss. Simonne Marie Anne Andree Laroche
#                         ...
# 826     Mrs. Antoni (Selini Alexander) Yasbeck
# 827             Master. George Sibley Richards
# 849                   Miss. Mary Conover Lines
# 865             Master. Harold Theodor Johnson
# 871                   Miss. Adele Kiamie Najib
# Name: Name, Length: 65, dtype: object

# %% [markdown]
# ## Задание 3
# Сделайте индексом колонку Name

# %%
# ваш код тут
n = titanic.set_index("Name")
n
# Out:
#                                                     Survived  ...     Fare
# Name                                                          ...
# Mr. Owen Harris Braund                                     0  ...   7.2500
# Mrs. John Bradley (Florence Briggs Thayer) Cumings         1  ...  71.2833
# Miss. Laina Heikkinen                                      1  ...   7.9250
# Mrs. Jacques Heath (Lily May Peel) Futrelle                1  ...  53.1000
# Mr. William Henry Allen                                    0  ...   8.0500
# ...                                                      ...  ...      ...
# Rev. Juozas Montvila                                       0  ...  13.0000
# Miss. Margaret Edith Graham                                1  ...  30.0000
# Miss. Catherine Helen Johnston                             0  ...  23.4500
# Mr. Karl Howell Behr                                       1  ...  30.0000
# Mr. Patrick Dooley                                         0  ...   7.7500
#
# [887 rows x 8 columns]

# %% [markdown]
# ## Задание 4
# Выберите возраст, и колонку Survived всех людей у которых в имени есть слово Henry

# %%
# ваш код тут
hen = titanic[titanic['Name'].str.contains("Henry")]
hen[['Name','Survived','Age']]
# Out:
#                                                   Name  Survived   Age
# 4                              Mr. William Henry Allen         0  35.0
# 12                       Mr. William Henry Saundercock         0  20.0
# 51             Mrs. Henry Sleeper (Myna Haxtun) Harper         1  49.0
# 61                          Mr. Henry Birkhardt Harris         0  45.0
# 158                          Master. Thomas Henry Sage         0   5.0
# 175                       Master. Henry Forbes Lefebre         0   5.0
# 208                                    Mr. Henry Blank         1  40.0
# 211                              Mr. John Henry Perkin         0  22.0
# 221                             Mr. George Henry Green         0  51.0
# 229        Mrs. Henry Birkhardt (Irene Wallach) Harris         1  35.0
# 238                              Mr. George Henry Hunt         0  33.0
# 262                                  Miss. Delia Henry         0  21.0
# 269                        Mr. William Henry Tornquist         1  25.0
# 332  Mrs. Henry William (Clara Heinsheimer) Frauenthal         1  42.0
# 345           Mrs. Thomas Henry (Mary E Finck) Davison         1  34.0
# 383                           Mr. Charles Henry Davies         0  18.0
# 409                                     Mr. Henry Hart         0  27.0
# 473                             Mr. Peter Henry Renouf         0  34.0
# 479                            Mr. Richard Henry Rouse         0  50.0
# 505                            Mr. Henry Margido Olsen         0  28.0
# 591                             Mr. John Henry Chapman         0  37.0
# 620                         Mr. Henry Damsgaard Hansen         0  21.0
# 627                Mr. Algernon Henry Wilson Barkworth         1  80.0
# 630                       Mr. William Henry Marsh Parr         0  30.0
# 642                           Mr. Henry Sleeper Harper         1  48.0
# 657                       Dr. Henry William Frauenthal         1  50.0
# 669                         Mr. Henry Michael Mitchell         0  70.0
# 692                          Mr. Charles Henry Chapman         0  52.0
# 702                            Mr. Henry Samuel Morley         0  39.0
# 718                        Mr. William Henry Gillespie         0  34.0
# 719                             Mr. Henry Price Hodges         0  50.0
# 722         Mrs. Peter Henry (Lillian Jefferys) Renouf         1  30.0
# 880                              Mr. Henry Jr Sutehall         0  25.0

# %% [markdown]
# ## Задание 5
# Посчитайте среднюю выживаемость в зависимости от приставки в имени.
#
# *Подсказка: приставка -- первое слово, или то слово, которое обозначается через точку (см результат для Henry). Воспользуйтесь groupby и строковыми методами работы .str*

# %%
t_c=titanic
t_c
# Out:
#      Survived  Pclass  ... Parents/Children Aboard     Fare
# 0           0       3  ...                       0   7.2500
# 1           1       1  ...                       0  71.2833
# 2           1       3  ...                       0   7.9250
# 3           1       1  ...                       0  53.1000
# 4           0       3  ...                       0   8.0500
# ..        ...     ...  ...                     ...      ...
# 882         0       2  ...                       0  13.0000
# 883         1       1  ...                       0  30.0000
# 884         0       3  ...                       2  23.4500
# 885         1       1  ...                       0  30.0000
# 886         0       3  ...                       0   7.7500
#
# [887 rows x 8 columns]

# %%
# создание колонки с приставкой имени
t_c.insert(3, 'Pr', t_c.Name.str.extract(r'([^.]*)', expand=False))

# %%
titanic
# Out:
#      Survived  Pclass  ... Parents/Children Aboard     Fare
# 0           0       3  ...                       0   7.2500
# 1           1       1  ...                       0  71.2833
# 2           1       3  ...                       0   7.9250
# 3           1       1  ...                       0  53.1000
# 4           0       3  ...                       0   8.0500
# ..        ...     ...  ...                     ...      ...
# 882         0       2  ...                       0  13.0000
# 883         1       1  ...                       0  30.0000
# 884         0       3  ...                       2  23.4500
# 885         1       1  ...                       0  30.0000
# 886         0       3  ...                       0   7.7500
#
# [887 rows x 8 columns]

# %%
# группируем по колонке
titanic.groupby(['Pr']).mean().unstack()['Survived']
# Out:
# Pr
# Capt            0.000000
# Col             0.500000
# Don             0.000000
# Dr              0.428571
# Jonkheer        0.000000
# Lady            1.000000
# Major           0.500000
# Master          0.575000
# Miss            0.697802
# Mlle            1.000000
# Mme             1.000000
# Mr              0.157895
# Mrs             0.792000
# Ms              1.000000
# Rev             0.000000
# Sir             1.000000
# the Countess    1.000000
# dtype: float64

# %% [markdown]
# ## Задание 6
# Постройте общее распределение выживших и невыживших

# %%
# ваш код тут
import pandas as pd
import matplotlib as plt
import numpy as np
import matplotlib.pyplot as plt

x=titanic['Survived']

plt.hist(x, bins='auto', density=True)
plt.title('График выживших и невыживших', fontsize=15)
plt.ylabel('Количество')
# Out:
# Text(0, 0.5, 'Количество')

# %% [markdown]
# ## Задание 7
# С помощью pairplot постройте попарные графики с раскраской по полю Survived.

# %%
# ваш код тут

sns_plot = sns.pairplot(titanic, hue='Survived')

# %% [markdown]
# ## Задание 9
# Точки накладываются друг на друга, не очень понятно что происходит, найдите способ отобразить точки с параметром прозрачности и снова постройте pairplot.
#
# *Подсказка: гугл.*

# %%
# ваш код тут
#sns_plot = sns.pairplot (titanic, hue='Survived', plot_kws={'alpha':0.5})
sns_plot = sns.pairplot (titanic, hue='Survived', palette='Set1')

# %% [markdown]
# ## Задание 10
# Теперь мы лучше видим концентрацию точек, давайте посмотрим более детально на разрез возраст/класс/пол пассажира.
#
# Сделайте FacetGrid в разбиении по Pclass.
#
# Вы можете найти полезным вот [этот материал](https://nagornyy.me/courses/data-science/intro-to-seaborn/#facet-grid)

# %%
# ваш код тут
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


t=sns.FacetGrid(titanic, col='Sex', row='Pclass', hue='Survived', size=3.2, aspect=2)
t.map(plt.hist,'Age', alpha=0.3, density=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Задание 11
# Постройте еще какой-нибудь интересный по вашему мнению график, приведенный в материале выше. Объясните почему вы построили именно его.

# %%
# распределение выживших в зависимости от количества родственников

tf=titanic.pivot_table('Survived', index='Siblings/Spouses Aboard')
tf.plot(kind='bar', stacked=True, )
tf
# Out:
#                          Survived
# Siblings/Spouses Aboard
# 0                        0.347682
# 1                        0.535885
# 2                        0.464286
# 3                        0.250000
# 4                        0.166667
# 5                        0.000000
# 8                        0.000000

# %% [markdown]
# ## Задание 12
# Постройте сводную таблицу (pivot_table), отражающую долю выживших, класс пассажира и его пол, используя groupby + unstack

# %%
# ваш код тут
titanic.groupby(['Sex', 'Pclass']).mean().unstack()['Survived']
# Out:
# Pclass         1         2         3
# Sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.137026

# %% [markdown]
# ## Задание 13
# Постройте сводную таблицу (pivot_table), отражающую долю выживших, класс пассажира и его пол, используя метод pivot_table

# %%
# ваш код тут
titanic.pivot_table(index=['Sex', 'Pclass'])['Survived']
# Out:
# Sex     Pclass
# female  1         0.968085
#         2         0.921053
#         3         0.500000
# male    1         0.368852
#         2         0.157407
#         3         0.137026
# Name: Survived, dtype: float64

# %% [markdown]
# ## Задание 14
# Попробуйте найти еще какой-нибудь фактор выживаемости с помощью доступных вам сейчас методов.
#
# Т.е, используя выборки, аггрегацию, графики

# %%
# ваш код тут 
#разбила выживших на группы по возрасту и оценила процент выживыших в каждой группе
titanic['Age_pr']=pd.cut(titanic['Age'],[0,18,30,90])
v=titanic.pivot_table(index='Age_pr')['Survived']
v.plot(kind='bar', stacked=True, )
